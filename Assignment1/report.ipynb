# %% [markdown]
# ## Assignment 3: Physical Activities Analysis with CWD

# %% [markdown]
# First step is to import the libraries useful for the analysis.

# %%
import pandas as pd
import pywt
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA_PATH = "./data/data.csv"
FAMILY = "mexh"

# from Kregg documentation
LABELS_NAME = ['Working at Computer', 'Standing Up, Walking and Going up\down stairs', 
                'Standing', 'Walking', 'Going Up\Down Stairs', 
                'Walking and Talking with Someone', 'Talking while Standing']

SAMPLING_HZ = 52

# %%
activities = pd.read_csv(DATA_PATH, names=["x", "y", "z", "label"], index_col=0)

activities.head()
# Out:
#         x     y     z  label
# 0.0  1984  1998  1645      1
# 1.0  1984  2003  1653      1
# 2.0  1987  2002  1648      1
# 3.0  1990  2001  1650      1
# 4.0  1992  2000  1657      1

# %%
activities[activities.label == 2]['x']
# Out:
# 44150

# %%
widths = np.geomspace(1, 1024, num=100)
cwtmatr, freqs = pywt.cwt(activities[activities.label == 1]['x'].to_numpy(), widths, FAMILY)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(cwtmatr, extent=[0, len(activities.index), 1, max(widths)], aspect='auto', cmap='jet')

plt.colorbar(label='Coefficients Magnitude')
plt.title('Continuous Wavelet Transform')
plt.xlabel('Time')
plt.ylabel('Scale')
plt.show()
